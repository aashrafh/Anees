# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/anees")

# %%
# !pip install -r requirements.txt --quiet
# Out:
#      |████████████████████████████████| 776.7 MB 4.3 kB/s
#      |████████████████████████████████| 3.1 MB 62.3 MB/s
#      |████████████████████████████████| 298 kB 72.6 MB/s
#      |████████████████████████████████| 1.2 MB 69.4 MB/s
#      |████████████████████████████████| 5.8 MB 59.5 MB/s
#      |████████████████████████████████| 54 kB 3.7 MB/s
#      |████████████████████████████████| 745 kB 82.8 MB/s
#      |████████████████████████████████| 57 kB 6.3 MB/s
#      |████████████████████████████████| 596 kB 86.2 MB/s
#      |████████████████████████████████| 101 kB 12.3 MB/s
#      |████████████████████████████████| 3.3 MB 55.2 MB/s
#      |████████████████████████████████| 880 kB 88.7 MB/s
#      |████████████████████████████████| 1.1 MB 81.3 MB/s
#      |████████████████████████████████| 212 kB 92.6 MB/s
#      |████████████████████████████████| 140 kB 102.6 MB/s
#      |████████████████████████████████| 63 kB 2.4 MB/s
#      |████████████████████████████████| 80 kB 11.6 MB/s
# ...

# %%
# !python src/api.py --mode='interact'
# Out:
# Loading the ARZ model...
# Loading the tokenizer...
# Loading the model...
# Loading the trained checkpoint...
# The interaction will start with the specified checkpoint.
# Loading the MSA model...
# Loading the tokenizer...
# Loading the model...
# Loading the trained checkpoint...
# The interaction will start with the specified checkpoint.
# Setting up the API...
# Public URL: http://4f6d-35-237-130-184.ngrok.io
# INFO:     Started server process [768]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     35.196.132.85:0 - "GET / HTTP/1.1" 200 OK
# [{'isUser': 1, 'message': 'مرحبا'}, {'isUser': 0, 'message': 'مرحبا ، أنا ( جيري ) كيف حالك ؟'}]
# INFO:     197.46.191.55:0 - "POST /msa HTTP/1.1" 200 OK
# ...
