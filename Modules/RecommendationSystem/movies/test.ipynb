# %%
import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import requests
# Out:
# E:\Anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
reqs = []

# %%
API_KEY = "k_oes3vdeb"
films_done_last_20_years_list_id = "ls054005416"

# %%
req = requests.get(f'https://imdb-api.com/API/IMDbList/{API_KEY}/{"ls099449475/"}')

# %%
req.json()
# Out:
# {'title': 'Egyptian movies',
#  'by': 'kingfhefire',
#  'created': '05 May 2020',
#  'updated': '10 May 2020',
#  'description': '',
#  'items': [{'id': 'tt1272034',
#    'index': '101',
#    'title': 'Boushkash',
#    'fullTitle': 'Boushkash (2008)',
#    'year': '2008',
#    'image': 'https://imdb-api.com/images/original/MV5BMmIyNTU1NzUtOTVjMS00YjUyLThhOGItOWFmZmUwMTk2ZDZjXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_Ratio0.7200_AL_.jpg',
#    'imDbRating': '5.3',
#    'imDbRatingCount': '881',
#    'description': 'Ahmed Yousry (dir.), Muhammad Sad, Zeina'},
#   {'id': 'tt2210441',
#    'index': '102',
#    'title': 'Bittersweet',
#    'fullTitle': 'Bittersweet (2010)',
#    'year': '2010',
#    'image': 'https://imdb-api.com/images/original/MV5BOGEyMjkwMGYtM2ZlMi00NWU2LThmNDYtNTlkMDVmM2ZjMjhiXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_Ratio0.7200_AL_.jpg',
#    'imDbRating': '7.9',
#    'imDbRatingCount': '6554',
#    'description': 'Khalid Marie (dir.), Ahmed Helmy, Idward'},
#   {'id': 'tt2210509',
# ...

# %%
reqs.append(req)
# Out:
# 200
